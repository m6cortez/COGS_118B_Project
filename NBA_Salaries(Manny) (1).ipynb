# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
nba_salaries= pd.read_csv("salaries_1985to2018.csv")
nba_players=pd.read_csv("players.csv")
frames=[nba_players,nba_salaries]
pd.set_option('display.max_rows',500)

# %%
nba_salaries.head()
nba_salaries.shape
# Out:
# (14163, 7)

# %%
nba_salaries=nba_salaries[nba_salaries.season_start>=1990]
nba_salaries=nba_salaries[nba_salaries.season_start<=2016]
nba_salaries
# Out:
#       league  player_id   salary   season  season_end  season_start  \
# 0        NBA  abdelal01   395000  1990-91        1991          1990
# 1        NBA  abdelal01   494000  1991-92        1992          1991
# 2        NBA  abdelal01   500000  1992-93        1993          1992
# 3        NBA  abdelal01   805000  1993-94        1994          1993
# 4        NBA  abdelal01   650000  1994-95        1995          1994
# ...      ...        ...      ...      ...         ...           ...
# 14155    NBA  zidekge01   694000  1996-97        1997          1996
# 14156    NBA  zidekge01   784200  1997-98        1998          1997
# 14157    NBA  zimmest01   950000  2016-17        2017          2016
# 14158    NBA  zipsepa01   750000  2016-17        2017          2016
# 14161    NBA  zubaciv01  1034956  2016-17        2017          2016
#
#                          team
# 0      Portland Trail Blazers
# 1      Portland Trail Blazers
# 2              Boston Celtics
# 3              Boston Celtics
# 4            Sacramento Kings
# ...                       ...
# 14155       Charlotte Hornets
# 14156          Denver Nuggets
# 14157           Orlando Magic
# 14158           Chicago Bulls
# 14161      Los Angeles Lakers
#
# [12378 rows x 7 columns]

# %%
#nba_salaries['salary'] = nba_salaries.apply(lambda x: cpi.inflate(x.salary, x.season_start), axis=1)

# %%
nba_salaries = nba_salaries.groupby(['player_id'], as_index=False).mean()
nba_salaries
# Out:
#       player_id        salary   season_end  season_start
# 0     abdelal01  5.688000e+05  1993.000000   1992.000000
# 1     abdulma02  2.205500e+06  1995.222222   1994.222222
# 2     abdulta01  3.798280e+06  2002.500000   2001.500000
# 3     abdursh01  8.715091e+06  2003.909091   2002.909091
# 4     abrinal01  5.994764e+06  2017.000000   2016.000000
# ...         ...           ...          ...           ...
# 2113  zhizhwa01  1.146368e+06  2003.600000   2002.600000
# 2114  zidekge01  6.937333e+05  1997.000000   1996.000000
# 2115  zimmest01  9.500000e+05  2017.000000   2016.000000
# 2116  zipsepa01  7.500000e+05  2017.000000   2016.000000
# 2117  zubaciv01  1.034956e+06  2017.000000   2016.000000
#
# [2118 rows x 4 columns]

# %%
nba_salaries=nba_salaries.drop(columns=['season_end', 'season_start'])
nba_salaries
# Out:
#       player_id        salary
# 0     abdelal01  5.688000e+05
# 1     abdulma02  2.205500e+06
# 2     abdulta01  3.798280e+06
# 3     abdursh01  8.715091e+06
# 4     abrinal01  5.994764e+06
# ...         ...           ...
# 2113  zhizhwa01  1.146368e+06
# 2114  zidekge01  6.937333e+05
# 2115  zimmest01  9.500000e+05
# 2116  zipsepa01  7.500000e+05
# 2117  zubaciv01  1.034956e+06
#
# [2118 rows x 2 columns]

# %%
nba_salaries=nba_salaries.round({"salary":1})

# %%
height_col = []
for index, value in nba_players['height'].iteritems():
    feet, inches = value.split("-")
    print(feet,inches)
    height = int(feet) * 12 + int(inches)
    height_col.append(height)
height_col= pd.Series(height_col)
nba_players["height"] = height_col
# Out:
# 6 10
# 6 9
# 7 2
# 6 1
# 6 6
# 6 9
# 6 7
# 6 3
# 6 3
# 6 6
# 6 5
# 6 0
# 6 11
# 6 6
# 6 7
# 6 9
# 6 6
# 6 5
# 6 4
# 6 2
# 6 5
# 5 10
# 7 0
# 6 7
# 6 10
# 6 7
# 6 1
# 6 7
# 6 5
# 6 5
# 6 6
# 6 2
# 6 4
# 6 7
# 7 2
# 6 10
# 5 11
# 6 6
# 7 1
# 6 8
# 6 9
# 6 10
# 6 11
# 6 11
# 6 11
# 6 8
# 6 1
# 6 5
# 6 7
# 6 8
# 6 9
# 6 2
# 6 5
# 6 8
# 6 9
# 6 5
# 6 11
# 6 4
# 6 3
# 6 9
# 6 2
# 6 10
# 6 8
# 6 5
# 6 4
# 6 6
# 6 6
# 6 11
# 6 9
# 6 6
# 6 11
# 6 2
# 6 10
# 6 10
# 6 8
# 6 9
# 6 9
# 6 3
# 6 10
# 6 11
# 6 6
# 6 2
# 6 6
# 6 2
# 6 10
# 6 2
# 6 5
# 6 3
# 6 9
# 6 10
# 6 8
# 6 6
# 6 5
# 6 6
# 6 0
# 6 7
# 6 9
# 5 11
# 6 6
# 6 10
# 6 7
# 6 10
# 6 6
# 6 7
# 6 7
# 7 2
# 6 7
# 6 10
# 6 7
# 7 0
# 6 11
# 6 10
# 6 7
# 6 8
# 6 0
# 6 9
# 6 11
# 6 8
# 6 1
# 6 11
# 6 4
# 6 11
# 6 1
# 6 3
# 6 8
# 6 3
# 6 8
# 6 4
# 6 9
# 6 2
# 6 8
# 6 5
# 5 11
# 6 0
# 6 11
# 6 3
# 6 5
# 6 2
# 6 5
# 6 2
# 6 9
# 6 4
# 6 7
# 7 0
# 6 6
# 6 7
# 6 2
# 6 2
# 5 11
# 6 0
# 5 10
# 6 8
# 6 0
# 6 10
# 6 10
# 6 0
# 6 9
# 6 9
# 6 1
# 6 2
# 6 10
# 6 10
# 6 9
# 7 1
# 6 5
# 6 5
# 6 9
# 7 0
# 6 2
# 6 7
# 6 3
# 6 4
# 7 1
# 6 0
# 6 11
# 7 0
# 6 5
# 6 9
# 6 11
# 6 6
# 6 9
# 6 9
# 6 1
# 6 1
# 6 0
# 6 4
# 6 11
# 6 4
# 6 8
# 6 8
# 6 6
# 6 7
# 6 4
# 7 0
# 6 7
# 6 2
# 6 10
# 6 9
# 6 9
# 6 6
# 6 3
# 6 5
# 6 0
# 7 0
# 6 2
# 6 11
# 6 6
# 6 1
# 6 6
# 6 8
# 6 3
# 6 8
# 6 8
# 6 7
# 6 4
# 6 4
# 6 3
# 6 1
# 6 4
# 6 4
# 6 3
# 6 3
# 6 4
# 5 10
# 6 3
# 6 2
# 7 0
# 5 11
# 6 6
# 6 5
# 6 4
# 6 7
# 6 5
# 7 0
# 6 6
# 6 5
# 6 7
# 6 8
# 6 8
# 6 8
# 6 9
# 6 10
# 6 10
# 6 9
# 6 7
# 6 2
# 6 9
# 6 1
# 6 3
# 6 7
# 6 9
# 6 5
# 6 2
# 6 8
# 6 2
# 6 1
# 6 8
# 6 5
# 6 7
# 6 3
# 6 7
# 6 6
# 6 1
# 6 2
# 6 10
# 6 3
# 6 3
# 6 8
# 6 10
# 6 10
# 6 1
# 6 9
# 6 9
# 6 7
# 6 6
# 6 6
# 6 7
# 6 8
# 6 4
# 6 7
# 6 7
# 6 2
# 6 6
# 7 0
# 6 8
# 6 3
# 6 4
# 6 8
# 6 3
# 6 3
# 6 10
# 6 8
# 6 2
# 6 7
# 6 6
# 5 10
# 6 4
# 6 8
# 6 0
# 6 5
# 6 3
# 6 5
# 6 7
# 6 10
# 6 5
# 6 1
# 6 8
# 6 2
# 6 5
# 6 8
# 6 6
# 6 1
# 6 7
# 6 8
# 7 0
# 6 4
# 6 8
# 6 2
# 6 5
# 7 0
# 7 0
# 6 8
# 6 6
# 6 7
# 6 2
# 6 11
# 6 10
# 6 4
# 6 6
# 5 10
# 6 10
# 6 9
# 6 7
# 6 3
# 7 1
# 6 8
# 5 10
# 6 7
# 6 5
# 6 10
# 6 9
# 6 2
# 6 9
# 6 7
# 6 6
# 5 9
# 6 5
# 6 9
# 6 7
# 6 3
# 6 11
# 6 10
# 6 8
# 6 1
# 6 5
# 6 9
# 6 8
# 6 3
# 6 8
# 6 8
# 6 1
# 6 9
# 6 2
# 6 11
# 7 2
# 6 11
# 6 6
# 6 6
# 6 2
# 6 8
# 6 7
# 6 5
# 6 7
# 6 8
# 6 2
# 6 9
# 6 3
# 6 6
# 6 2
# 6 7
# 6 7
# 6 7
# 6 5
# 6 6
# 6 8
# 7 0
# 6 2
# 6 9
# 6 2
# 6 7
# 7 0
# 6 1
# 6 3
# 6 4
# 6 11
# 7 0
# 6 8
# 6 10
# 7 0
# 7 0
# 6 3
# 7 0
# 6 8
# 6 11
# 7 1
# 6 1
# 7 1
# 6 3

# %%
nba_player=nba_players[nba_players.draft_year>='1985']
nba_player.head()
# Out:
#          _id          birthDate                birthPlace  career_AST  \
# 0  abdelal01      June 24, 1968              Cairo, Egypt         0.3
# 3  abdulma02      March 9, 1969     Gulfport, Mississippi         3.5
# 4  abdulta01   November 3, 1974    Maisons Alfort, France         1.1
# 5  abdursh01  December 11, 1976         Marietta, Georgia         2.5
# 9  abrinal01     August 1, 1993  Palma de Mallorca, Spain         0.5
#
#   career_FG% career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 0       50.2         0.0       70.1       256       13.0         5.7  ...
# 3       44.2        35.4       90.5       586       15.4        14.6  ...
# 4       41.7        23.7       70.3       236       11.4         7.8  ...
# 5       47.2        29.7       81.0       830       19.0        18.1  ...
# 9       38.7        36.8       88.0       174        8.8         5.3  ...
#
#      draft_pick draft_round              draft_team draft_year height  \
# 0  25th overall   1st round  Portland Trail Blazers       1990     82
# 3   3rd overall   1st round          Denver Nuggets       1990     73
# 4  11th overall   1st round        Sacramento Kings       1997     78
# 5   3rd overall   1st round     Vancouver Grizzlies       1996     81
# 9  32nd overall   2nd round   Oklahoma City Thunder       2013     78
#
#                                 highSchool                 name  \
# 0     Bloomfield in Bloomfield, New Jersey       Alaa Abdelnaby
# 3        Gulfport in Gulfport, Mississippi   Mahmoud Abdul-Rauf
# 4  Lycee Aristide Briand in Evreux, France    Tariq Abdul-Wahad
# 5             Wheeler in Marietta, Georgia  Shareef Abdur-Rahim
# 9                                      NaN         Alex Abrines
#
#                                      position  shoots weight
# 0                               Power Forward   Right  240lb
# 3                                 Point Guard   Right  162lb
# 4                              Shooting Guard   Right  223lb
# 5  Center and Small Forward and Power Forward   Right  225lb
# 9                              Shooting Guard   Right  200lb
#
# [5 rows x 24 columns]

# %%
nba_players=nba_players.drop(columns=[ 'birthPlace', 'college', 'highSchool', 'birthDate',"shoots", 'draft_pick', \
                                     'draft_round', 'draft_year', 'draft_team','weight'])
nba_players=nba_players[['name','_id','position', 'height'
           ,'career_AST', 'career_FG%', 'career_FG3%','career_FT%', 'career_G', 'career_PER', 'career_PTS', 'career_TRB', 'career_WS', 'career_eFG%']]
nba_players.head()
# Out:
#                   name        _id                  position  height  \
# 0       Alaa Abdelnaby  abdelal01             Power Forward      82
# 1      Zaid Abdul-Aziz  abdulza01  Power Forward and Center      81
# 2  Kareem Abdul-Jabbar  abdulka01                    Center      86
# 3   Mahmoud Abdul-Rauf  abdulma02               Point Guard      73
# 4    Tariq Abdul-Wahad  abdulta01            Shooting Guard      78
#
#    career_AST career_FG% career_FG3% career_FT%  career_G career_PER  \
# 0         0.3       50.2         0.0       70.1       256       13.0
# 1         1.2       42.8         NaN       72.8       505       15.1
# 2         3.6       55.9         5.6       72.1      1560       24.6
# 3         3.5       44.2        35.4       90.5       586       15.4
# 4         1.1       41.7        23.7       70.3       236       11.4
#
#    career_PTS career_TRB career_WS career_eFG%
# 0         5.7        3.3       4.8        50.2
# 1         9.0        8.0      17.5         NaN
# 2        24.6       11.2     273.4        55.9
# 3        14.6        1.9      25.2        47.2
# 4         7.8        3.3       3.5        42.2

# %%
nba_players=nba_players.dropna(how = 'any')

# %%
nba_players.rename(columns = {"career_FG%" : "careerFG", "career_FG3%" : "careerFG3", "career_FT%" : "careerFT", "career_eFG%":'careereFG', 
                             "career_G":'careerG',"career_PTS":'careerPTS', "career_PER":'careerPER', 
                              "career_TRB":'careerTRB', "career_WS":'careerWS', "career_AST":'careerAST'} , inplace = True)

# %%
nba_players=nba_players.drop_duplicates(subset='name')

# %%
nba_players.shape
# Out:
# (3525, 14)

# %%
print(nba_players['name'].value_counts())
# Out:
# Jason Caffey        1
# Willie Worsley      1
# Elvin Ivory         1
# Lawrence Roberts    1
# Oliver Miller       1
#                    ..
# Thurl Bailey        1
# Gary Forbes         1
# Nate McMillan       1
# Ronald Taylor       1
# Billy Paultz        1
# Name: name, Length: 3525, dtype: int64

# %%
def tidy_split(df, column, sep='|', keep=False):
    """
    Split the values of a column and expand so the new DataFrame has one split
    value per row. Filters rows where the column is missing.

    Params
    ------
    df : pandas.DataFrame
        dataframe with the column to split and expand
    column : str
        the column to split and expand
    sep : str
        the string used to split the column's values
    keep : bool
        whether to retain the presplit value as it's own row

    Returns
    -------
    pandas.DataFrame
        Returns a dataframe with the same columns as `df`.
    """
    indexes = list()
    new_values = list()
    df = df.dropna(subset=[column])
    for i, presplit in enumerate(df[column].astype(str)):
        values = presplit.split(sep)
        if keep and len(values) > 1:
            indexes.append(i)
            new_values.append(presplit)
        for value in values:
            indexes.append(i)
            new_values.append(value)
    new_df = df.iloc[indexes, :].copy()
    new_df[column] = new_values
    return new_df

# %%
nba_players= tidy_split(nba_players,'position', sep=' and ')
nba_players
# Out:
#                      name        _id        position  height  careerAST  \
# 0          Alaa Abdelnaby  abdelal01   Power Forward      82        0.3
# 2     Kareem Abdul-Jabbar  abdulka01          Center      86        3.6
# 3      Mahmoud Abdul-Rauf  abdulma02     Point Guard      73        3.5
# 4       Tariq Abdul-Wahad  abdulta01  Shooting Guard      78        1.1
# 5     Shareef Abdur-Rahim  abdursh01          Center      81        2.5
# ...                   ...        ...             ...     ...        ...
# 4678    Stephen Zimmerman  zimmest01          Center      84        0.2
# 4679          Paul Zipser  zipsepa01   Small Forward      80        0.8
# 4680           Ante Zizic  zizican01          Center      83        0.6
# 4681             Jim Zoet   zoetji01          Center      85        0.1
# 4683          Ivica Zubac  zubaciv01          Center      85        0.8
#
#      careerFG careerFG3 careerFT  careerG careerPER  careerPTS careerTRB  \
# 0        50.2       0.0     70.1      256      13.0        5.7       3.3
# 2        55.9       5.6     72.1     1560      24.6       24.6      11.2
# 3        44.2      35.4     90.5      586      15.4       14.6       1.9
# 4        41.7      23.7     70.3      236      11.4        7.8       3.3
# 5        47.2      29.7     81.0      830      19.0       18.1       7.5
# ...       ...       ...      ...      ...       ...        ...       ...
# 4678     32.3         -     60.0       19       7.3        1.2       1.8
# 4679     37.1      33.5     76.9       98       6.1        4.7       2.6
# 4680     58.3         -     70.8       91      17.5        6.4       4.2
# 4681     20.0         -        -        7      -0.8        0.3       1.1
# 4683     54.0       0.0     76.1      140      17.6        6.9       4.6
#
#      careerWS careereFG
# 0         4.8      50.2
# 2       273.4      55.9
# 3        25.2      47.2
# 4         3.5      42.2
# 5        71.2      47.9
# ...       ...       ...
# 4678      0.0      32.3
# 4679      0.0      44.8
# 4680      3.0      58.3
# 4681     -0.1      20.0
# 4683      5.3      54.0
#
# [4615 rows x 14 columns]

# %%
nba_players=nba_players.drop_duplicates(subset='name')

print(nba_players['name'].value_counts())
# Out:
# Jason Caffey        1
# Willie Worsley      1
# Elvin Ivory         1
# Lawrence Roberts    1
# Oliver Miller       1
#                    ..
# Thurl Bailey        1
# Gary Forbes         1
# Nate McMillan       1
# Ronald Taylor       1
# Billy Paultz        1
# Name: name, Length: 3525, dtype: int64

# %%
nba_players = nba_players[nba_players.careerFG != "-"]
nba_players = nba_players[nba_players.careerFG3 != "-"]
nba_players = nba_players[nba_players.careerFT!= "-"]
nba_players = nba_players[nba_players.careerPER != "-"]
nba_players = nba_players[nba_players.careerTRB != "-"]
nba_players = nba_players[nba_players.careerWS != "-"]
nba_players = nba_players[nba_players.careereFG != "-"]
nba_players.shape
# Out:
# (2979, 14)

# %%
nba_players
# Out:
#                      name        _id        position  height  careerAST  \
# 0          Alaa Abdelnaby  abdelal01   Power Forward      82        0.3
# 2     Kareem Abdul-Jabbar  abdulka01          Center      86        3.6
# 3      Mahmoud Abdul-Rauf  abdulma02     Point Guard      73        3.5
# 4       Tariq Abdul-Wahad  abdulta01  Shooting Guard      78        1.1
# 5     Shareef Abdur-Rahim  abdursh01          Center      81        2.5
# ...                   ...        ...             ...     ...        ...
# 4672         Tyler Zeller  zellety01          Center      84        0.9
# 4675          Wang Zhizhi  zhizhwa01          Center      84        0.3
# 4676         George Zidek  zidekge01          Center      84        0.2
# 4679          Paul Zipser  zipsepa01   Small Forward      80        0.8
# 4683          Ivica Zubac  zubaciv01          Center      85        0.8
#
#      careerFG careerFG3 careerFT  careerG careerPER  careerPTS careerTRB  \
# 0        50.2       0.0     70.1      256      13.0        5.7       3.3
# 2        55.9       5.6     72.1     1560      24.6       24.6      11.2
# 3        44.2      35.4     90.5      586      15.4       14.6       1.9
# 4        41.7      23.7     70.3      236      11.4        7.8       3.3
# 5        47.2      29.7     81.0      830      19.0       18.1       7.5
# ...       ...       ...      ...      ...       ...        ...       ...
# 4672     50.9      28.6     76.4      412      14.9        7.0       4.4
# 4675     41.7      38.5     73.5      137      14.2        4.4       1.7
# 4676     40.8      25.0     78.3      135       8.7        3.4       2.1
# 4679     37.1      33.5     76.9       98       6.1        4.7       2.6
# 4683     54.0       0.0     76.1      140      17.6        6.9       4.6
#
#      careerWS careereFG
# 0         4.8      50.2
# 2       273.4      55.9
# 3        25.2      47.2
# 4         3.5      42.2
# 5        71.2      47.9
# ...       ...       ...
# 4672     17.1      51.1
# 4675      2.1      48.5
# 4676      0.8      40.9
# 4679      0.0      44.8
# 4683      5.3      54.0
#
# [2979 rows x 14 columns]

# %%
nba_players.head()
# Out:
#                   name        _id        position  height  careerAST careerFG  \
# 0       Alaa Abdelnaby  abdelal01   Power Forward      82        0.3     50.2
# 2  Kareem Abdul-Jabbar  abdulka01          Center      86        3.6     55.9
# 3   Mahmoud Abdul-Rauf  abdulma02     Point Guard      73        3.5     44.2
# 4    Tariq Abdul-Wahad  abdulta01  Shooting Guard      78        1.1     41.7
# 5  Shareef Abdur-Rahim  abdursh01          Center      81        2.5     47.2
#
#   careerFG3 careerFT  careerG careerPER  careerPTS careerTRB careerWS  \
# 0       0.0     70.1      256      13.0        5.7       3.3      4.8
# 2       5.6     72.1     1560      24.6       24.6      11.2    273.4
# 3      35.4     90.5      586      15.4       14.6       1.9     25.2
# 4      23.7     70.3      236      11.4        7.8       3.3      3.5
# 5      29.7     81.0      830      19.0       18.1       7.5     71.2
#
#   careereFG
# 0      50.2
# 2      55.9
# 3      47.2
# 4      42.2
# 5      47.9

# %%
nba_stats=pd.merge(nba_players, nba_salaries, right_on='player_id',left_on='_id')
nba_stats=nba_stats.drop_duplicates(subset='name')
nba_stats=nba_stats.drop(columns=['_id','player_id'])
nba_stats.sort_values(by=['salary'], ascending=False)
# Out:
#                   name        position  height  careerAST careerFG careerFG3  \
# 232        Kobe Bryant  Shooting Guard      78        4.7     44.7      32.9
# 574      Kevin Garnett   Small Forward      83        3.7     49.7      27.5
# 1249  Shaquille O'Neal          Center      85        2.5     58.2       4.5
# 57     Carmelo Anthony   Small Forward      80        3.0     44.9      34.7
# 785      Dwight Howard   Power Forward      83        1.5     58.3       9.5
# ...                ...             ...     ...        ...      ...       ...
# 562       Corey Gaines  Shooting Guard      75        3.1     42.4      22.9
# 1269       Matt Othick     Point Guard      74        1.8     60.0      50.0
# 187         Ira Bowman     Point Guard      77        0.5     63.6       0.0
# 1857     Howard Wright   Power Forward      80        0.2     44.2       0.0
# 1475      Jason Sasser   Small Forward      79        0.3     41.2      33.3
#
#      careerFT  careerG careerPER  careerPTS careerTRB careerWS careereFG  \
# 232      83.7     1346      22.9       25.0       5.2    172.7      48.2
# 574      78.9     1462      22.7       17.8      10.0    191.4      50.1
# 1249     52.7     1207      26.4       23.7      10.9    181.7      58.2
# 57       81.1     1064      20.3       24.0       6.5    101.0      48.2
# 785      56.7     1044      21.6       17.4      12.6    128.9      58.3
# ...       ...      ...       ...        ...       ...      ...       ...
# 562      73.6       80      10.8        3.1       0.9      1.1      44.9
# 1269      0.0        4       5.9        2.0       0.5      0.0      80.0
# 187      50.0       17      13.4        0.9       0.3      0.2      63.6
# 1857     61.5       19       9.8        3.3       2.5      0.1      44.2
# 1475     50.0       14       7.6        2.1       1.1      0.0      42.6
#
#           salary
# 232   16411903.1
# 574   15630563.5
# 1249  15378859.3
# 57    14696975.4
# 785   14635835.5
# ...          ...
# 562      13000.0
# 1269     13000.0
# 187      12158.0
# 1857      5000.0
# 1475      2706.0
#
# [1876 rows x 14 columns]

# %%
nba_stats=nba_stats.reset_index(drop=True)
nba_stats.head()
# Out:
#                   name        position  height  careerAST careerFG careerFG3  \
# 0       Alaa Abdelnaby   Power Forward      82        0.3     50.2       0.0
# 1   Mahmoud Abdul-Rauf     Point Guard      73        3.5     44.2      35.4
# 2    Tariq Abdul-Wahad  Shooting Guard      78        1.1     41.7      23.7
# 3  Shareef Abdur-Rahim          Center      81        2.5     47.2      29.7
# 4         Alex Abrines  Shooting Guard      78        0.5     38.7      36.8
#
#   careerFT  careerG careerPER  careerPTS careerTRB careerWS careereFG  \
# 0     70.1      256      13.0        5.7       3.3      4.8      50.2
# 1     90.5      586      15.4       14.6       1.9     25.2      47.2
# 2     70.3      236      11.4        7.8       3.3      3.5      42.2
# 3     81.0      830      19.0       18.1       7.5     71.2      47.9
# 4     88.0      174       8.8        5.3       1.4      5.0      52.5
#
#       salary
# 0   568800.0
# 1  2205500.0
# 2  3798280.0
# 3  8715090.9
# 4  5994764.0

# %%
nba_stats['position']=nba_stats['position'].str.strip()

# %%
dummy_pos=pd.get_dummies(nba_stats['position'], dummy_na=False)
nba_stats=pd.concat([nba_stats,dummy_pos], axis=1)
nba_stats
# Out:
#                      name        position  height  careerAST careerFG  \
# 0          Alaa Abdelnaby   Power Forward      82        0.3     50.2
# 1      Mahmoud Abdul-Rauf     Point Guard      73        3.5     44.2
# 2       Tariq Abdul-Wahad  Shooting Guard      78        1.1     41.7
# 3     Shareef Abdur-Rahim          Center      81        2.5     47.2
# 4            Alex Abrines  Shooting Guard      78        0.5     38.7
# ...                   ...             ...     ...        ...      ...
# 1871         Tyler Zeller          Center      84        0.9     50.9
# 1872          Wang Zhizhi          Center      84        0.3     41.7
# 1873         George Zidek          Center      84        0.2     40.8
# 1874          Paul Zipser   Small Forward      80        0.8     37.1
# 1875          Ivica Zubac          Center      85        0.8     54.0
#
#      careerFG3 careerFT  careerG careerPER  careerPTS careerTRB careerWS  \
# 0          0.0     70.1      256      13.0        5.7       3.3      4.8
# 1         35.4     90.5      586      15.4       14.6       1.9     25.2
# 2         23.7     70.3      236      11.4        7.8       3.3      3.5
# 3         29.7     81.0      830      19.0       18.1       7.5     71.2
# 4         36.8     88.0      174       8.8        5.3       1.4      5.0
# ...        ...      ...      ...       ...        ...       ...      ...
# 1871      28.6     76.4      412      14.9        7.0       4.4     17.1
# 1872      38.5     73.5      137      14.2        4.4       1.7      2.1
# 1873      25.0     78.3      135       8.7        3.4       2.1      0.8
# 1874      33.5     76.9       98       6.1        4.7       2.6      0.0
# 1875       0.0     76.1      140      17.6        6.9       4.6      5.3
#
#      careereFG     salary  Center  Point Guard  Power Forward  Shooting Guard  \
# 0         50.2   568800.0       0            0              1               0
# 1         47.2  2205500.0       0            1              0               0
# 2         42.2  3798280.0       0            0              0               1
# 3         47.9  8715090.9       1            0              0               0
# 4         52.5  5994764.0       0            0              0               1
# ...        ...        ...     ...          ...            ...             ...
# 1871      51.1  3103459.0       1            0              0               0
# 1872      48.5  1146367.8       1            0              0               0
# 1873      40.9   693733.3       1            0              0               0
# 1874      44.8   750000.0       0            0              0               0
# 1875      54.0  1034956.0       1            0              0               0
#
#       Small Forward
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1871              0
# 1872              0
# 1873              0
# 1874              1
# 1875              0
#
# [1876 rows x 19 columns]

# %%
th1=nba_stats[(nba_stats.salary >=0 ) & (nba_stats.salary <=4000000)]
th2=nba_stats[(nba_stats.salary >=4000000) & (nba_stats.salary <=8000000)]
th3=nba_stats[(nba_stats.salary >=8000000) & (nba_stats.salary <=12000000)]
th4=nba_stats[(nba_stats.salary >=12000000) & (nba_stats.salary <=20000000)]
nba_stats['Salary_lvl'] = pd.cut(nba_stats['salary'], bins=[0, 3000000, 6000000,9000000,  float('Inf')], labels=['rookie_deal','veteran_min', 'max','super_max'])
nba_stats
# Out:
#                      name        position  height  careerAST careerFG  \
# 0          Alaa Abdelnaby   Power Forward      82        0.3     50.2
# 1      Mahmoud Abdul-Rauf     Point Guard      73        3.5     44.2
# 2       Tariq Abdul-Wahad  Shooting Guard      78        1.1     41.7
# 3     Shareef Abdur-Rahim          Center      81        2.5     47.2
# 4            Alex Abrines  Shooting Guard      78        0.5     38.7
# ...                   ...             ...     ...        ...      ...
# 1871         Tyler Zeller          Center      84        0.9     50.9
# 1872          Wang Zhizhi          Center      84        0.3     41.7
# 1873         George Zidek          Center      84        0.2     40.8
# 1874          Paul Zipser   Small Forward      80        0.8     37.1
# 1875          Ivica Zubac          Center      85        0.8     54.0
#
#      careerFG3 careerFT  careerG careerPER  careerPTS careerTRB careerWS  \
# 0          0.0     70.1      256      13.0        5.7       3.3      4.8
# 1         35.4     90.5      586      15.4       14.6       1.9     25.2
# 2         23.7     70.3      236      11.4        7.8       3.3      3.5
# 3         29.7     81.0      830      19.0       18.1       7.5     71.2
# 4         36.8     88.0      174       8.8        5.3       1.4      5.0
# ...        ...      ...      ...       ...        ...       ...      ...
# 1871      28.6     76.4      412      14.9        7.0       4.4     17.1
# 1872      38.5     73.5      137      14.2        4.4       1.7      2.1
# 1873      25.0     78.3      135       8.7        3.4       2.1      0.8
# 1874      33.5     76.9       98       6.1        4.7       2.6      0.0
# 1875       0.0     76.1      140      17.6        6.9       4.6      5.3
#
#      careereFG     salary  Center  Point Guard  Power Forward  Shooting Guard  \
# 0         50.2   568800.0       0            0              1               0
# 1         47.2  2205500.0       0            1              0               0
# 2         42.2  3798280.0       0            0              0               1
# 3         47.9  8715090.9       1            0              0               0
# 4         52.5  5994764.0       0            0              0               1
# ...        ...        ...     ...          ...            ...             ...
# 1871      51.1  3103459.0       1            0              0               0
# 1872      48.5  1146367.8       1            0              0               0
# 1873      40.9   693733.3       1            0              0               0
# 1874      44.8   750000.0       0            0              0               0
# 1875      54.0  1034956.0       1            0              0               0
#
#       Small Forward   Salary_lvl
# 0                 0  rookie_deal
# 1                 0  rookie_deal
# 2                 0  veteran_min
# 3                 0          max
# 4                 0  veteran_min
# ...             ...          ...
# 1871              0  veteran_min
# 1872              0  rookie_deal
# 1873              0  rookie_deal
# 1874              1  rookie_deal
# 1875              0  rookie_deal
#
# [1876 rows x 20 columns]

# %%
nba_stats['Salary_lvl'].value_counts()
# Out:
# rookie_deal    1397
# veteran_min     307
# max             118
# super_max        54
# Name: Salary_lvl, dtype: int64

# %%
nba_stats.salary.max()
# Out:
# 16411903.1

# %%
nba_stats['careerFG'] = nba_stats['careerFG'].astype(float)
nba_stats['careerFG3'] = nba_stats['careerFG3'].astype(float)
nba_stats['careerFT'] = nba_stats['careerFT'].astype(float)
nba_stats['careerPER'] = nba_stats['careerPER'].astype(float)
nba_stats['careerTRB'] = nba_stats['careerTRB'].astype(float)
nba_stats['careerWS'] = nba_stats['careerWS'].astype(float)
nba_stats['careereFG'] = nba_stats['careereFG'].astype(float)

# %%
nba_stats.to_csv("NBA_Career_Data.csv", index=False)
